# %%
predicted_disease = "Influenza"
symptoms = ["fever", "cough", "fatigue"]

# %%
from google import genai

client = genai.Client()

prompt = "Top Predictions: Disease: Gastroenteritis, Confidence: 51.0% Disease: GERD, Confidence: 11.0% Disease: Common Cold, Confidence: 9.0%.... you have to explain the user these diesease and there symptoms"

response = client.models.generate_content(
    model="gemma-3-27b-it",
    contents=prompt
)

print(response.text)
# Out:
# Okay, let's break down these potential diagnoses based on the provided predictions. It's important to remember **I am an AI and cannot provide medical advice.** This information is for educational purposes only, and you should *always* consult a doctor for a proper diagnosis and treatment plan.  The confidence levels suggest Gastroenteritis is the most likely, but all possibilities should be considered.
#
# Here's an explanation of each disease and its symptoms, based on the information provided:
#
# **1. Gastroenteritis (Confidence: 51.0%) - Most Likely**
#
# * **What it is:** Gastroenteritis, often called "stomach flu" (though it's *not* related to the influenza virus), is an inflammation of the stomach and intestines. It's usually caused by a viral or bacterial infection, or sometimes by parasites.
# * **Symptoms:**
#     * **Diarrhea:**  Frequent, loose, watery stools. This is a hallmark symptom.
#     * **Vomiting:**  Can be forceful and frequent.
# ...

# %% [markdown]
# Here is a summary of the possible conditions based on your symptoms.
#
# Reported symptoms:
# - nodal skin eruptions
# - continuous sneezing
# - shivering
# - chills
# - joint pain
#
# Possible conditions identified by the model:
# 1. Allergy — 66.5% confidence
# 2. Fungal infection — 22.0% confidence
# 3. Psoriasis — 6.5% confidence
#
# Confidence Interpretation Rules:
# *   **Allergy (66.5% confidence):** Your symptoms strongly match patterns associated with an allergy. This is largely due to the presence of continuous sneezing and shivering.
# *   **Fungal infection (22.0% confidence):** Your symptoms show a moderate match with a fungal infection. This is influenced by the presence of shivering and continuous sneezing.
# *   **Psoriasis (6.5% confidence):** Your symptoms only weakly match psoriasis, and the model is uncertain. Nodal skin eruptions contribute to this low confidence, but also slightly decrease the likelihood of this diagnosis.
#
# Please remember this information is only guidance, and you should consult a healthcare professional for a proper diagnosis.

# %%
s = "abcdef"
s[:3]
# Out:
# 'abc'
